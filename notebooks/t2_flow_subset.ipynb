# %% [markdown]
# # Tranalayzer Small-subset Pre-processing
#
# This notebook is intended for storing a small subset of the dataset for mixed_flows, benign_flows and features. Run instead of tran_feature_selection when running subsequent notebooks without a GPU

# %%
import pandas as pd

# %%
## This cell was used to extract the subsets from the full flow datasets.
## The subsequent cells will read the sample inputs from csvs stored in the git repo

# %store -r mixed_flows
# %store -r benign_flows
# %store -r features

# benign_flows.sample(n=50000, random_state=42).to_csv('benign/tran_benign_50k_sample.csv')
# mixed_attack_flows = mixed_flows[mixed_flows["is_attack"] == True].sample(n=25000, random_state=42)
# mixed_benign_flows = mixed_flows[mixed_flows["is_attack"] == False].sample(n=25000, random_state=42)
## sample frac 1 returns all samples (but shuffled)
# mixed_flows = pd.concat([mixed_benign_flows, mixed_attack_flows], axis=0).sample(frac=1).to_csv('attack/tran_mixed_50k_sample.csv')

# %%
benign_flows = pd.read_csv('benign/tran_benign_50k_sample.csv', index_col=0)
# %store benign_flows
benign_flows
# Out:
# Stored 'benign_flows' (DataFrame)
#          %dir  flowInd            flowStat     timeFirst      timeLast  \
# 6577968     B   535787  0x0400000000004001  1.539482e+09  1.539482e+09
# 1056433     A    18582  0x0400000000004000  1.529134e+09  1.529134e+09
# 184146      B     1165  0x0400000000004001  1.527727e+09  1.527727e+09
# 10593457    B    22694  0x0400000000004001  1.539806e+09  1.539806e+09
# 7709398     B   416492  0x0400000000004001  1.539578e+09  1.539578e+09
# ...       ...      ...                 ...           ...           ...
# 5528758     B      181  0x0400000000004001  1.539436e+09  1.539436e+09
# 2733562     B   113063  0x0400000000004001  1.539213e+09  1.539213e+09
# 1122395     A    54357  0x0400000000004000  1.529189e+09  1.529189e+09
# 161453      B    38328  0x0400000000004001  1.527704e+09  1.527704e+09
# 1381804     A    23393  0x0400000000004000  1.529400e+09  1.529400e+09
#
#             duration  numHdrDesc  numHdrs       hdrDesc             srcMac  \
# 6577968     3.253930           1        3  eth:ipv4:tcp  14:cc:20:51:33:ea
# 1056433     1.665139           1        3  eth:ipv4:tcp  ec:1a:59:83:28:11
# 184146      0.037608           1        3  eth:ipv4:tcp  00:16:6c:ab:6b:88
# 10593457    0.034228           1        3  eth:ipv4:tcp  00:16:6c:ab:6b:88
# 7709398     0.044728           1        3  eth:ipv4:tcp  ec:1a:59:7a:02:c5
# ...              ...         ...      ...           ...                ...
# 5528758   750.069941           1        3  eth:ipv4:tcp  14:cc:20:51:33:ea
# 2733562     2.637292           1        3  eth:ipv4:tcp  14:cc:20:51:33:ea
# 1122395     2.109892           1        3  eth:ipv4:tcp  ec:1a:59:83:28:11
# 161453      0.038587           1        3  eth:ipv4:tcp  00:16:6c:ab:6b:88
# 1381804    10.196206           1        3  eth:ipv4:tcp  e0:76:d0:3f:00:ae
#
#           ... icmpTCcnt          icmpBFTypH_TypL_Code   icmpTmGtw  \
# 6577968   ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 1056433   ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 184146    ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 10593457  ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 7709398   ...         0  0x00000000_0x00000000_0x0000  0x00000000
# ...       ...       ...                           ...         ...
# 5528758   ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 2733562   ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 1122395   ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 161453    ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 1381804   ...         0  0x00000000_0x00000000_0x0000  0x00000000
#
#          icmpEchoSuccRatio icmpPFindex connSip  connDip connSipDip  \
# 6577968                0.0           0       1        7          3
# 1056433                0.0           0      10        1          3
# 184146                 0.0           0       1        9          3
# 10593457               0.0           0       2       10         11
# 7709398                0.0           0       2        8          1
# ...                    ...         ...     ...      ...        ...
# 5528758                0.0           0       1        2          1
# 2733562                0.0           0       1        8          3
# 1122395                0.0           0       9        1          2
# 161453                 0.0           0       1       10          3
# 1381804                0.0           0       7        1          4
#
#          connSipDprt     connF
# 6577968            3  3.000000
# 1056433            3  0.300000
# 184146             3  3.000000
# 10593457          11  5.500000
# 7709398            7  3.500000
# ...              ...       ...
# 5528758            3  3.000000
# 2733562            3  3.000000
# 1122395            2  0.222222
# 161453             3  3.000000
# 1381804           10  1.428571
#
# [50000 rows x 106 columns]

# %%
mixed_flows = pd.read_csv('attack/tran_mixed_50k_sample.csv', index_col=0)
# %store mixed_flows
mixed_flows
# Out:
# Stored 'mixed_flows' (DataFrame)
#         %dir  flowInd            flowStat     timeFirst      timeLast  \
# 1500550    A    72982  0x0400000000004000  1.540277e+09  1.540277e+09
# 1872310    B    24539  0x0400000000004001  1.540404e+09  1.540404e+09
# 49248      B    27018  0x0400000000004001  1.527853e+09  1.527853e+09
# 206517     B   107716  0x0400000000004001  1.527892e+09  1.527892e+09
# 89902      B    48152  0x0400000000004001  1.527868e+09  1.527868e+09
# ...      ...      ...                 ...           ...           ...
# 1105466    A     4925  0x0400000000004000  1.529460e+09  1.529460e+09
# 724852     B    61276  0x0400000000004001  1.528232e+09  1.528232e+09
# 557049     A    29290  0x0400000000004000  1.528114e+09  1.528114e+09
# 601614     A    52757  0x0400000000004000  1.528150e+09  1.528151e+09
# 181494     B    94928  0x0400000000004001  1.527887e+09  1.527887e+09
#
#            duration  numHdrDesc  numHdrs       hdrDesc  \
# 1500550    0.000896           1        3  eth:ipv4:tcp
# 1872310    0.012015           1        3  eth:ipv4:tcp
# 49248      0.000000           1        3  eth:ipv4:tcp
# 206517     0.000000           1        3  eth:ipv4:tcp
# 89902      0.000000           1        3  eth:ipv4:tcp
# ...             ...         ...      ...           ...
# 1105466    2.120534           1        3  eth:ipv4:tcp
# 724852     0.000000           1        3  eth:ipv4:tcp
# 557049    10.168299           1        3  eth:ipv4:tcp
# 601614   240.176317           1        3  eth:ipv4:tcp
# 181494     0.000000           1        3  eth:ipv4:tcp
#
#                                       srcMac  ...  \
# 1500550  2c:27:d7:3b:e1:05;08:2e:5f:25:88:e5  ...
# 1872310                    ec:1a:59:83:28:11  ...
# 49248                      ec:1a:59:83:28:11  ...
# 206517                     00:16:6c:ab:6b:88  ...
# 89902                      50:c7:bf:00:56:39  ...
# ...                                      ...  ...
# 1105466                    ec:1a:59:83:28:11  ...
# 724852                     50:c7:bf:00:56:39  ...
# 557049                     e0:76:d0:3f:00:ae  ...
# 601614                     f4:f5:d8:d4:eb:12  ...
# 181494                     ec:1a:59:79:f4:89  ...
#
#                  icmpBFTypH_TypL_Code   icmpTmGtw  icmpEchoSuccRatio  \
# 1500550  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 1872310  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 49248    0x00000000_0x00000000_0x0000  0x00000000                0.0
# 206517   0x00000000_0x00000000_0x0000  0x00000000                0.0
# 89902    0x00000000_0x00000000_0x0000  0x00000000                0.0
# ...                               ...         ...                ...
# 1105466  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 724852   0x00000000_0x00000000_0x0000  0x00000000                0.0
# 557049   0x00000000_0x00000000_0x0000  0x00000000                0.0
# 601614   0x00000000_0x00000000_0x0000  0x00000000                0.0
# 181494   0x00000000_0x00000000_0x0000  0x00000000                0.0
#
#         icmpPFindex connSip connDip  connSipDip connSipDprt     connF  \
# 1500550           0       1       1           2           2  2.000000
# 1872310           0       6       5           4           3  0.500000
# 49248             0       4       1           1           1  0.250000
# 206517            0       1       2           1           1  1.000000
# 89902             0       1       1           1           1  1.000000
# ...             ...     ...     ...         ...         ...       ...
# 1105466           0       9       1           2           2  0.222222
# 724852            0       1       1           1           1  1.000000
# 557049            0       6       1           4          10  1.666667
# 601614            0       8       1           4           6  0.750000
# 181494            0       2       1           1           1  0.500000
#
#         is_attack
# 1500550     False
# 1872310      True
# 49248        True
# 206517       True
# 89902        True
# ...           ...
# 1105466      True
# 724852       True
# 557049      False
# 601614      False
# 181494       True
#
# [50000 rows x 107 columns]

# %%
features = ['flowInd', 'duration', 'numHdrDesc',
            'l4Proto', 'macPairs', 'dstPortClassN', 'numPktsSnt', 'numPktsRcvd',
            'numBytesSnt', 'numBytesRcvd', 'minPktSz', 'maxPktSz', 'avePktSize', 'stdPktSize', 'pktps', 'bytps',
            'pktAsm', 'bytAsm', 'ipMindIPID', 'ipMaxdIPID', 'ipMinTTL', 'ipMaxTTL', 'ipTTLChg', 'ipOptCnt',
            'tcpPSeqCnt', 'tcpSeqSntBytes', 'tcpSeqFaultCnt', 'tcpPAckCnt', 'tcpFlwLssAckRcvdBytes', 'tcpAckFaultCnt',
            'tcpInitWinSz', 'tcpAveWinSz', 'tcpMinWinSz', 'tcpMaxWinSz', 'tcpWinSzDwnCnt', 'tcpWinSzUpCnt',
            'tcpWinSzChgDirCnt', 'tcpOptPktCnt', 'tcpOptCnt', 'tcpMSS', 'tcpWS', 'tcpTmS', 'tcpTmER', 'tcpEcI',
            'tcpBtm', 'tcpSSASAATrip', 'tcpRTTAckTripMin', 'tcpRTTAckTripMax', 'tcpRTTAckTripAve',
            'tcpRTTAckTripJitAve', 'tcpRTTSseqAA', 'tcpRTTAckJitAve', 'icmpTCcnt', 'icmpEchoSuccRatio', 'icmpPFindex',
            'connSip', 'connDip', 'connSipDip', 'connSipDprt', 'connF',  'aveIAT', 'maxIAT', 
                'stdIAT', 'tcpISeqN', 'tcpUtm', 'tcpWinSzThRt']

# %store features
# Out:
# Stored 'features' (list)
