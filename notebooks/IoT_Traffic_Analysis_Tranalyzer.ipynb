# %% [markdown]
# <a href="https://colab.research.google.com/github/MackPreston/iot-traffic-analysis/blob/main/IoT_Traffic_Analysis_Tranalyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # IoT Traffic Analysis with Tranalyzer Flows

# %%
import sys
import os
import glob
import pandas as pd
import numpy as np
from datetime import datetime

time_to_date = lambda t: datetime.utcfromtimestamp(t).strftime('%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## Loading benign dataset
#
# The dataset is then loadeded from tranalyzers output into a dataframe

# %%
print("Current Directory:" + os.getcwd())
# file_pattern = '*_flows.txt' # Use all pcap files
file_pattern = '18-05-29_flows.txt'
glob_path = os.path.join(os.getcwd(), 'benign/tran', file_pattern)
file_list = glob.glob(glob_path)

li = []
for filepath in file_list:
    df = pd.read_csv(filepath, index_col=None, header=0, delimiter='\t')
    li.append(df)

benign_flows = pd.concat(li, axis=0, ignore_index=True)
benign_flows
# Out:
# Current Directory:/mnt/e/iot-traffic-analysis
# /home/mack/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#       %dir  flowInd            flowStat     timeFirst      timeLast  \
# 0        A        2  0x0400000000004000  1.527552e+09  1.527552e+09
# 1        B        2  0x0400000000004001  1.527552e+09  1.527552e+09
# 2        A        3  0x0400000000004000  1.527552e+09  1.527552e+09
# 3        B        3  0x0400000000004001  1.527552e+09  1.527552e+09
# 4        A       24  0x0400000000004000  1.527552e+09  1.527552e+09
# ...    ...      ...                 ...           ...           ...
# 90926    B    47443  0x0400000000004001  1.527635e+09  1.527638e+09
# 90927    A    49217  0x0400000000004000  1.527638e+09  1.527638e+09
# 90928    B    49217  0x0400000000004001  1.527638e+09  1.527638e+09
# 90929    A        1  0x0400000000004000  1.527552e+09  1.527638e+09
# 90930    B        1  0x0400000000004001  1.527552e+09  1.527638e+09
#
#            duration  numHdrDesc numHdrs       hdrDesc             srcMac  ...  \
# 0          0.012182           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea  ...
# 1          0.001862           1       3  eth:ipv4:tcp  ec:1a:59:83:28:11  ...
# 2          2.146254           1       3  eth:ipv4:tcp  ec:1a:59:83:28:11  ...
# 3          1.922308           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea  ...
# 4          0.012025           1       3  eth:ipv4:tcp  ec:1a:59:83:28:11  ...
# ...             ...         ...     ...           ...                ...  ...
# 90926   3514.705441           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea  ...
# 90927     45.225318           1       3  eth:ipv4:tcp  f4:f5:d8:d4:eb:12  ...
# 90928     45.224967           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea  ...
# 90929  86397.810988           1       3  eth:ipv4:tcp  30:8c:fb:2f:e4:b2  ...
# 90930  86397.761764           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea  ...
#
#       icmpTCcnt          icmpBFTypH_TypL_Code   icmpTmGtw icmpEchoSuccRatio  \
# 0             0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 1             0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 2             0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 3             0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 4             0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# ...         ...                           ...         ...               ...
# 90926         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 90927         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 90928         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 90929         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 90930         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
#
#       icmpPFindex connSip  connDip connSipDip connSipDprt connF
# 0               0       1        1          2           2   2.0
# 1               0       1        1          1           1   1.0
# 2               0       1        1          2           2   2.0
# 3               0       1        1          1           1   1.0
# 4               0       5        1          4           4   0.8
# ...           ...     ...      ...        ...         ...   ...
# 90926           0       1        1          1           1   1.0
# 90927           0       1        1          2           2   2.0
# 90928           0       1        1          1           1   1.0
# 90929           0       1        1          2           2   2.0
# 90930           0       1        1          1           1   1.0
#
# [90931 rows x 106 columns]

# %% [markdown]
# # Loading Mixed Dataset

# %%
import os
import glob
print("Current Directory:" + os.getcwd())
# file_pattern = '*_flows.txt' # Use all pcap files
file_pattern = '18-06-01_flows.txt'
glob_path = os.path.join(os.getcwd(), 'attack/tran', file_pattern)
file_list = glob.glob(glob_path)

li = []
for filepath in file_list:
    df = pd.read_csv(filepath, index_col=None, header=0, delimiter='\t')
    li.append(df)

mixed_flows = pd.concat(li, axis=0, ignore_index=True)
mixed_flows
# Out:
# Current Directory:/mnt/e/iot-traffic-analysis
# /home/mack/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#        %dir  flowInd            flowStat     timeFirst      timeLast  \
# 0         A        1  0x0400000000004000  1.527823e+09  1.527823e+09
# 1         B        1  0x0400000000004001  1.527823e+09  1.527823e+09
# 2         A        2  0x0400000000004000  1.527823e+09  1.527823e+09
# 3         B        2  0x0400000000004001  1.527823e+09  1.527823e+09
# 4         A        7  0x0400000000004000  1.527823e+09  1.527823e+09
# ...     ...      ...                 ...           ...           ...
# 226479    B   117860  0x0400000000004001  1.527897e+09  1.527897e+09
# 226480    A      120  0x0400000000004000  1.527823e+09  1.527897e+09
# 226481    B      120  0x0400000000004001  1.527823e+09  1.527897e+09
# 226482    A   117861  0x0800000000008000  1.527897e+09  1.527897e+09
# 226483    A   117862  0x0400000000004000  1.527897e+09  1.527897e+09
#
#             duration  numHdrDesc numHdrs       hdrDesc             srcMac  \
# 0           0.190275           1       3  eth:ipv4:tcp  e0:76:d0:3f:00:ae
# 1           0.000187           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea
# 2          10.196861           1       3  eth:ipv4:tcp  e0:76:d0:3f:00:ae
# 3          10.007584           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea
# 4          10.196851           1       3  eth:ipv4:tcp  e0:76:d0:3f:00:ae
# ...              ...         ...     ...           ...                ...
# 226479      0.219089           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea
# 226480  74067.670764           1       3  eth:ipv4:tcp  30:8c:fb:2f:e4:b2
# 226481  74066.088314           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea
# 226482      0.000000           1       3  eth:ipv6:udp  e0:76:d0:3f:00:ae
# 226483      0.000000           1       3  eth:ipv4:udp  e0:76:d0:3f:00:ae
#
#         ... icmpTCcnt          icmpBFTypH_TypL_Code   icmpTmGtw  \
# 0       ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 1       ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 2       ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 3       ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 4       ...         0  0x00000000_0x00000000_0x0000  0x00000000
# ...     ...       ...                           ...         ...
# 226479  ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 226480  ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 226481  ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 226482  ...         0  0x00000000_0x00000000_0x0000  0x00000000
# 226483  ...         0  0x00000000_0x00000000_0x0000  0x00000000
#
#        icmpEchoSuccRatio icmpPFindex connSip  connDip connSipDip connSipDprt  \
# 0                    0.0           0       1        1          4           4
# 1                    0.0           0       1        1          3           3
# 2                    0.0           0       3        1          4           6
# 3                    0.0           0       1        3          3           5
# 4                    0.0           0       5        1          2           8
# ...                  ...         ...     ...      ...        ...         ...
# 226479               0.0           0       1        1          1           1
# 226480               0.0           0       1        1          2           2
# 226481               0.0           0       1        1          1           1
# 226482               0.0           0       1        1          1           1
# 226483               0.0           0       1        1          1           1
#
#        connF
# 0        4.0
# 1        3.0
# 2        2.0
# 3        5.0
# 4        1.6
# ...      ...
# 226479   1.0
# 226480   2.0
# 226481   1.0
# 226482   1.0
# 226483   1.0
#
# [226484 rows x 106 columns]

# %% [markdown]
# # Labeling Known Attack Flows
#
# Note: the original 50c7bf005639.csv source file had a few extra commas that needed to be removed in order to load the csv properly.
#
# TODO - investigate *-packet-anomaly.txt files - what are they for?

# %%
# Load device_info from file
mac_to_filename = lambda s: f"{s.lower().replace(':', '')}.csv"

filepath = "device_info.csv"
device_info = pd.read_csv(filepath, index_col=None, delimiter=',')
device_info['annotation_file'] = device_info['mac'].map(mac_to_filename)
device_info
# Out:
#                  mac             ip         device_type   annotation_file
# 0  ec:1a:59:83:28:11  192.168.1.165  WEMO Motion Sensor  ec1a59832811.csv
# 1  ec:1a:59:79:f4:89  192.168.1.223   WEMO Power Switch  ec1a5979f489.csv
# 2  00:16:6c:ab:6b:88  192.168.1.248      Samsung Camera  00166cab6b88.csv
# 3  50:c7:bf:00:56:39  192.168.1.227        TP Link Plug  50c7bf005639.csv
# 4  70:ee:50:18:34:43  192.168.1.241      Netatmo Camera  70ee50183443.csv
# 5  00:17:88:2B:9A:25  192.168.1.129             Huebulb  0017882b9a25.csv
# 6  44:65:0D:56:CC:D3  192.168.1.239          AmazonEcho  44650d56ccd3.csv
# 7  F4:F5:D8:8F:0A:3C  192.168.1.119          chromecast  f4f5d88f0a3c.csv
# 8  74:C6:3B:29:D7:1D  192.168.1.163               ihome  74c63b29d71d.csv
# 9  D0:73:D5:01:83:08  192.168.1.118                lifx  d073d5018308.csv

# %%
file_pattern = '*.csv'
glob_path = os.path.join(os.getcwd(), 'annotations', file_pattern)
file_list = glob.glob(glob_path)

li = []
for filepath in file_list:
    print(f"loading {filepath}")
    df = pd.read_csv(filepath, index_col=None, delimiter=',', header=0, names=[
      'start_time', 'end_time', 'description', 'attack_type'])
    
    filename = os.path.basename(filepath)
    df['annotation_file'] = filename
    li.append(df)

all_known_attacks = pd.concat(li, axis=0, ignore_index=True)
# Convert time units to match tranalyzer
all_known_attacks.sort_values(by=['start_time'], inplace=True, ignore_index=True)
all_known_attacks["duration"] = all_known_attacks['end_time'] - all_known_attacks['start_time']

# Enrich attack meta-data with device meta-data
all_known_attacks = all_known_attacks.set_index('annotation_file').join(device_info.set_index('annotation_file'))
all_known_attacks
# Out:
# loading /mnt/e/iot-traffic-analysis/annotations/00166cab6b88.csv
# loading /mnt/e/iot-traffic-analysis/annotations/0017882b9a25.csv
# loading /mnt/e/iot-traffic-analysis/annotations/44650d56ccd3.csv
# loading /mnt/e/iot-traffic-analysis/annotations/50c7bf005639.csv
# loading /mnt/e/iot-traffic-analysis/annotations/70ee50183443.csv
# loading /mnt/e/iot-traffic-analysis/annotations/74c63b29d71d.csv
# loading /mnt/e/iot-traffic-analysis/annotations/d073d5018308.csv
# loading /mnt/e/iot-traffic-analysis/annotations/ec1a5979f489.csv
# loading /mnt/e/iot-traffic-analysis/annotations/ec1a59832811.csv
# loading /mnt/e/iot-traffic-analysis/annotations/f4f5d88f0a3c.csv
#                   start_time    end_time  \
# annotation_file
# 00166cab6b88.csv  1527835334  1527835936
# 00166cab6b88.csv  1527836944  1527837544
# 00166cab6b88.csv  1527860996  1527861596
# 00166cab6b88.csv  1527862604  1527863204
# 00166cab6b88.csv  1527864215  1527864815
# ...                      ...         ...
# f4f5d88f0a3c.csv  1540314670  1540315270
# f4f5d88f0a3c.csv  1540315870  1540316470
# f4f5d88f0a3c.csv  1540452323  1540452924
# f4f5d88f0a3c.csv  1540453525  1540454125
# f4f5d88f0a3c.csv  1540462848  1540463448
#
#                                                         description  \
# annotation_file
# 00166cab6b88.csv              Localfeatures|Allfeatures|Arpfeatures
# 00166cab6b88.csv              Localfeatures|Allfeatures|Arpfeatures
# 00166cab6b88.csv  localTcpPort49152|Tcpfeatures|Localfeatures|Al...
# 00166cab6b88.csv  localTcpPort49152|Tcpfeatures|Localfeatures|Al...
# 00166cab6b88.csv  localTcpPort49152|Tcpfeatures|Localfeatures|Al...
# ...                                                             ...
# f4f5d88f0a3c.csv  Udpfeatures|Internetfeatures|Allfeatures|Inter...
# f4f5d88f0a3c.csv  Udpfeatures|Internetfeatures|Allfeatures|Inter...
# f4f5d88f0a3c.csv  Udpfeatures|Internetfeatures|Allfeatures|Inter...
# f4f5d88f0a3c.csv  Tcpfeatures|Internetfeatures|Allfeatures|Inter...
# f4f5d88f0a3c.csv  Tcpfeatures|Internetfeatures|Allfeatures|Inter...
#
#                                attack_type  duration                mac  \
# annotation_file
# 00166cab6b88.csv              ArpSpoof1L2D       602  00:16:6c:ab:6b:88
# 00166cab6b88.csv             ArpSpoof10L2D       600  00:16:6c:ab:6b:88
# 00166cab6b88.csv          TcpSynDevice1L2D       600  00:16:6c:ab:6b:88
# 00166cab6b88.csv         TcpSynDevice10L2D       600  00:16:6c:ab:6b:88
# 00166cab6b88.csv        TcpSynDevice100L2D       600  00:16:6c:ab:6b:88
# ...                                    ...       ...                ...
# f4f5d88f0a3c.csv               Ssdp10W2D2W       600  F4:F5:D8:8F:0A:3C
# f4f5d88f0a3c.csv              Ssdp100W2D2W       600  F4:F5:D8:8F:0A:3C
# f4f5d88f0a3c.csv                Ssdp1W2D2W       601  F4:F5:D8:8F:0A:3C
# f4f5d88f0a3c.csv    TcpSynReflection1W2D2W       600  F4:F5:D8:8F:0A:3C
# f4f5d88f0a3c.csv  TcpSynReflection100W2D2W       600  F4:F5:D8:8F:0A:3C
#
#                              ip     device_type
# annotation_file
# 00166cab6b88.csv  192.168.1.248  Samsung Camera
# 00166cab6b88.csv  192.168.1.248  Samsung Camera
# 00166cab6b88.csv  192.168.1.248  Samsung Camera
# 00166cab6b88.csv  192.168.1.248  Samsung Camera
# 00166cab6b88.csv  192.168.1.248  Samsung Camera
# ...                         ...             ...
# f4f5d88f0a3c.csv  192.168.1.119      chromecast
# f4f5d88f0a3c.csv  192.168.1.119      chromecast
# f4f5d88f0a3c.csv  192.168.1.119      chromecast
# f4f5d88f0a3c.csv  192.168.1.119      chromecast
# f4f5d88f0a3c.csv  192.168.1.119      chromecast
#
# [224 rows x 8 columns]

# %%
last_attack_endtime = max(all_known_attacks['end_time'])
last_flow_endtime = max(mixed_flows['timeLast'])

print(f"last known attack ended at {time_to_date(last_attack_endtime)}")
# TODO - investigate why the last attack happens on Oct 25, but there are two more days of mixed traffic (Oct 26, Oct 27)

# Filter out attacks that happened outside our current dataset
known_attacks = all_known_attacks[all_known_attacks['end_time'] <= last_flow_endtime]
known_attacks.reset_index()
print(f"Using {len(known_attacks)} of {len(all_known_attacks)} known attacks")

in_attack_window = (mixed_flows['duration'] < 605) & (mixed_flows['duration'] >= 600)
mixed_flows[in_attack_window]
# TODO - find a way to accurately correlate known attacks with their corresponding flows


# for attack_index, attack in all_known_attacks.iterrows():
#   print(len(mixed_flows[ (attack['start_time'] <= mixed_flows['timeFirst']) & (attack['end_time'] <= mixed_flows['timeLast']) ]))
# Out:
# last known attack ended at 2018-10-25 10:30:48
# Using 51 of 224 known attacks
#        %dir  flowInd            flowStat     timeFirst      timeLast  \
# 3011      A     1177  0x0000000000000044  1.527824e+09  1.527825e+09
# 5079      B     2285  0x0000000000000045  1.527826e+09  1.527826e+09
# 7426      B     3683  0x0400000000004001  1.527827e+09  1.527828e+09
# 9433      B     4716  0x0400000000004001  1.527829e+09  1.527829e+09
# 11337     B     5840  0x0000000000000045  1.527830e+09  1.527831e+09
# 11338     A     5824  0x0000000000000044  1.527830e+09  1.527831e+09
# 11339     B     5824  0x0000000000000045  1.527830e+09  1.527831e+09
# 18101     B     9572  0x0000000000000045  1.527835e+09  1.527836e+09
# 18105     B     9553  0x0000000000000045  1.527835e+09  1.527836e+09
# 22901     B    12198  0x0000000000000045  1.527839e+09  1.527839e+09
# 25234     B    13496  0x0000000000000045  1.527840e+09  1.527841e+09
# 66285     A    31344  0x0000000000000044  1.527858e+09  1.527858e+09
# 108866    A    55505  0x0000000000000044  1.527869e+09  1.527870e+09
# 111929    A    58283  0x0000000000000044  1.527871e+09  1.527871e+09
# 122994    A    60299  0x0000000000000044  1.527872e+09  1.527873e+09
# 133681    A    68373  0x0000000000000044  1.527874e+09  1.527874e+09
# 176284    A    91267  0x0000000000000044  1.527885e+09  1.527886e+09
# 197979    A   101375  0x0000000000000044  1.527888e+09  1.527889e+09
# 216228    A   111640  0x0000000000000044  1.527895e+09  1.527895e+09
#
#           duration  numHdrDesc numHdrs       hdrDesc             srcMac  ...  \
# 3011    603.690847           1       2       eth:arp  08:2e:5f:25:88:e5  ...
# 5079    600.133380           1       2       eth:arp  2c:27:d7:3b:e1:05  ...
# 7426    600.851074           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea  ...
# 9433    600.808793           1       3  eth:ipv4:tcp  14:cc:20:51:33:ea  ...
# 11337   600.148362           1       2       eth:arp  2c:27:d7:3b:e1:05  ...
# 11338   603.561384           1       2       eth:arp  14:cc:20:51:33:ea  ...
# 11339   600.295953           1       2       eth:arp  2c:27:d7:3b:e1:05  ...
# 18101   600.754558           1       2       eth:arp  2c:27:d7:3b:e1:05  ...
# 18105   600.865986           1       2       eth:arp  2c:27:d7:3b:e1:05  ...
# 22901   600.024037           1       2       eth:arp  2c:27:d7:3b:e1:05  ...
# 25234   600.024050           1       2       eth:arp  2c:27:d7:3b:e1:05  ...
# 66285   604.821868           1       2       eth:arp  ec:1a:59:79:f4:89  ...
# 108866  600.357077           1       2       eth:arp  50:c7:bf:00:56:39  ...
# 111929  604.656950           1       2       eth:arp  70:ee:50:18:34:43  ...
# 122994  601.229534           1       2       eth:arp  70:ee:50:18:34:43  ...
# 133681  602.338773           1       2       eth:arp  70:ee:50:18:34:43  ...
# 176284  601.590995           1       2       eth:arp  08:2e:5f:25:88:e5  ...
# 197979  601.437600           1       2       eth:arp  08:2e:5f:25:88:e5  ...
# 216228  600.598022           1       2       eth:arp  08:2e:5f:25:88:e5  ...
#
#        icmpTCcnt          icmpBFTypH_TypL_Code   icmpTmGtw icmpEchoSuccRatio  \
# 3011           0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 5079           0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 7426           0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 9433           0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 11337          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 11338          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 11339          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 18101          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 18105          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 22901          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 25234          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 66285          0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 108866         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 111929         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 122994         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 133681         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 176284         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 197979         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 216228         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
#
#        icmpPFindex connSip  connDip connSipDip connSipDprt connF
# 3011             0       0        0          0           0   0.0
# 5079             0       0        0          0           0   0.0
# 7426             0       1        9          1           1   1.0
# 9433             0       1        8          3           3   3.0
# 11337            0       0        0          0           0   0.0
# 11338            0       0        0          0           0   0.0
# 11339            0       0        0          0           0   0.0
# 18101            0       0        0          0           0   0.0
# 18105            0       0        0          0           0   0.0
# 22901            0       0        0          0           0   0.0
# 25234            0       0        0          0           0   0.0
# 66285            0       0        0          0           0   0.0
# 108866           0       0        0          0           0   0.0
# 111929           0       0        0          0           0   0.0
# 122994           0       0        0          0           0   0.0
# 133681           0       0        0          0           0   0.0
# 176284           0       0        0          0           0   0.0
# 197979           0       0        0          0           0   0.0
# 216228           0       0        0          0           0   0.0
#
# [19 rows x 106 columns]

# %% [markdown]
# # Feature Selection

# %%
# Features which will not be used
pointless_features = ['timeFirst', 'timeLast', 'dstPort', 'srcPort', 'dstIP', 
                      'dstMac', 'srcIP', 'srcMac', 'srcMac_dstMac_numP']

# Non-decimal features categorized by data-type
hex_features = ['flowStat', 'tcpFStat', 'ipTOS', 'ipFlags', 'ethType',
                 'tcpStates', 'icmpStat', 'icmpTmGtw', 'macStat','tcpAnomaly', 
                'tcpFlags',  'tcpMPF', 'tcpMPTBF', 'tcpMPdssF', 'tcpOptions']


string_features = ['%dir', 'hdrDesc', 'srcManuf_dstManuf', 'dstPortClass', 
                   'srcIPCC', 'dstIPCC', 'dstIPOrg', 'srcIPOrg']

# Not sure what to make of these - more research required
underscore_features = ['ipOptCpCl_Num', 'icmpBFTypH_TypL_Code', 'ip6OptHH_D', 'ip6OptCntHH_D']

# Features we will use
features = ['flowInd', 'duration', 'numHdrDesc', 'numHdrs',
            'ethVlanID', 'l4Proto', 'macPairs', 'dstPortClassN', 'numPktsSnt', 'numPktsRcvd',
            'numBytesSnt', 'numBytesRcvd', 'minPktSz', 'maxPktSz', 'avePktSize', 'stdPktSize', 'pktps', 'bytps',
            'pktAsm', 'bytAsm', 'ipMindIPID', 'ipMaxdIPID', 'ipMinTTL', 'ipMaxTTL', 'ipTTLChg', 'ipOptCnt',
            'tcpPSeqCnt', 'tcpSeqSntBytes', 'tcpSeqFaultCnt', 'tcpPAckCnt', 'tcpFlwLssAckRcvdBytes', 'tcpAckFaultCnt',
            'tcpInitWinSz', 'tcpAveWinSz', 'tcpMinWinSz', 'tcpMaxWinSz', 'tcpWinSzDwnCnt', 'tcpWinSzUpCnt',
            'tcpWinSzChgDirCnt', 'tcpOptPktCnt', 'tcpOptCnt', 'tcpMSS', 'tcpWS', 'tcpTmS', 'tcpTmER', 'tcpEcI',
            'tcpBtm', 'tcpSSASAATrip', 'tcpRTTAckTripMin', 'tcpRTTAckTripMax', 'tcpRTTAckTripAve',
            'tcpRTTAckTripJitAve', 'tcpRTTSseqAA', 'tcpRTTAckJitAve', 'icmpTCcnt', 'icmpEchoSuccRatio', 'icmpPFindex',
            'connSip', 'connDip', 'connSipDip', 'connSipDprt', 'connF',  'aveIAT', 'maxIAT', 
                'minIAT', 'stdIAT', 'tcpISeqN', 'tcpMPAID', 'tcpUtm', 'tcpWinSzThRt']

unused_features = pointless_features + hex_features + string_features + underscore_features
all_features = features + unused_features

benign_flows[features]
