# %%
import sys
import os
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import collections
import torch.optim as optim
import torch.utils.data as data_utils

# %%
# %store -r benign_flows  
# %store -r mixed_flows
# %store -r features

# change flow according to the requirement

# df = benign_flows[features]
# name = 'benign'

# with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
#     print(df)

df = mixed_flows[features]
name = 'mixed'


ncols = 5
nrows = int(np.ceil(len(df.columns) / (1.0*ncols)))
fig, axes = plt.subplots(nrows=nrows, ncols=ncols,figsize=(350,300))
plt.title("Feature distribution")



cnt = 0
for i in range(nrows):
    for j in range(ncols):

        ax = axes[i][j]

        # Plot when we have data
        if cnt < len(features):

            ax.hist(df[df.columns[cnt]], bins = 200, color='blue',alpha = 0.8, label='{}'.format(df.columns[cnt]))
            ax.set_xlabel('x axis')
            ax.set_ylabel('y axis')
            
            leg = ax.legend(loc='upper right')
            leg.draw_frame(False)
            
        # Remove axis when data reading complete
        else:
            ax.set_axis_off()

        cnt += 1
plt.grid()

dirname = 'graphs'

if os.path.isdir(dirname) == False:
    try:
        os.mkdir(dirname)
        if name == 'benign':
            plt.savefig('graphs/{}_features.png'.format(name))
        elif name == 'mixed':
            plt.savefig('graphs/{}_features.png'.format(name))
        
    except OSError:
        print ("Creation of the directory %s failed" %dirname )
    else:
        print ("Successfully created the directory %s " % dirname)
# Out:
# Successfully created the directory graphs
