# %% [markdown]
# <a href="https://colab.research.google.com/github/MackPreston/iot-traffic-analysis/blob/main/notebooks/tran_sample_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tranalayzer Small-subset Pre-processing
#
# This notebook is intended for storing a small subset of the dataset for mixed_flows, benign_flows and features. Run instead of tran_feature_selection when running subsequent notebooks without a GPU

# %%
import pandas as pd

# %%
# This cell was used to extract the subsets from the full flow datasets.
# The subsequent cells will read the sample inputs from csvs stored in the git repo

# %store -r mixed_flows
# %store -r benign_flows
# %store -r features

# benign_flows.sample(n=50000, random_state=42).to_csv('benign/tran_benign_50k_sample.csv')
# mixed_flows.sample(n=50000, random_state=42).to_csv('attack/tran_mixed_50k_sample.csv')

# %%
benign_flows = pd.read_csv('benign/tran_benign_50k_sample.csv', index_col=0)
# %store benign_flows
benign_flows
# Out:
# /home/mack/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Stored 'benign_flows' (DataFrame)
#         %dir  flowInd            flowStat     timeFirst      timeLast  \
# 7746725    A   433982  0x0400000000004000  1.539578e+09  1.539578e+09
# 9302181    A   276630  0x0400000000004000  1.539660e+09  1.539660e+09
# 2722482    A   106766  0x0400000000004000  1.539206e+09  1.539206e+09
# 3984027    A   304720  0x0400000000004000  1.539325e+09  1.539325e+09
# 2030818    B   295424  0x0400000000004001  1.539151e+09  1.539151e+09
# ...      ...      ...                 ...           ...           ...
# 2646857    B    67271  0x0400000000004001  1.539185e+09  1.539185e+09
# 8736974    A   931183  0x0400000000004000  1.539608e+09  1.539608e+09
# 8158097    A   640550  0x0400000000004000  1.539592e+09  1.539592e+09
# 8154677    A   638855  0x0400000000004000  1.539592e+09  1.539592e+09
# 6274793    A   381206  0x0400000000004000  1.539469e+09  1.539469e+09
#
#          duration  numHdrDesc numHdrs       hdrDesc             srcMac  ...  \
# 7746725  0.000000           1       3  eth:ipv4:udp  f4:f5:d8:8f:0a:3c  ...
# 9302181  0.000000           1       3  eth:ipv4:udp  f4:f5:d8:8f:0a:3c  ...
# 2722482  8.688219           1       3  eth:ipv4:udp  ec:1a:59:83:28:11  ...
# 3984027  0.000000           1       3  eth:ipv4:udp  f4:f5:d8:8f:0a:3c  ...
# 2030818  0.000000           1       3  eth:ipv4:udp  14:cc:20:51:33:ea  ...
# ...           ...         ...     ...           ...                ...  ...
# 2646857  0.000000           1       3  eth:ipv4:udp  14:cc:20:51:33:ea  ...
# 8736974  0.000000           1       3  eth:ipv4:udp  f4:f5:d8:8f:0a:3c  ...
# 8158097  0.000000           1       3  eth:ipv4:udp  f4:f5:d8:8f:0a:3c  ...
# 8154677  0.000000           1       3  eth:ipv4:udp  f4:f5:d8:8f:0a:3c  ...
# 6274793  0.002737           1       3  eth:ipv4:udp  f4:f5:d8:8f:0a:3c  ...
#
#         icmpTCcnt          icmpBFTypH_TypL_Code   icmpTmGtw icmpEchoSuccRatio  \
# 7746725         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 9302181         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 2722482         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 3984027         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 2030818         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# ...           ...                           ...         ...               ...
# 2646857         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 8736974         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 8158097         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 8154677         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
# 6274793         0  0x00000000_0x00000000_0x0000  0x00000000               0.0
#
#         icmpPFindex connSip  connDip connSipDip connSipDprt        connF
# 7746725           0      10        4       4611        4609   460.900000
# 9302181           0       9        1       2200        2200   244.444400
# 2722482           0       9       11         16          10     1.111111
# 3984027           0      11        3       2214        2212   201.090900
# 2030818           0       2        9       2205        2203  1101.500000
# ...             ...     ...      ...        ...         ...          ...
# 2646857           0       1       12       1109        1109  1109.000000
# 8736974           0       9        3       4610        4608   512.000000
# 8158097           0      10        2       2497        2497   249.700000
# 8154677           0       9        4       4618        4616   512.888900
# 6274793           0      10        2       2188        2186   218.600000
#
# [50000 rows x 106 columns]

# %%
mixed_flows = pd.read_csv('attack/tran_mixed_50k_sample.csv', index_col=0)
# %store mixed_flows
mixed_flows
# Out:
# /home/mack/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3155: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Stored 'mixed_flows' (DataFrame)
#         %dir  flowInd            flowStat     timeFirst      timeLast  \
# 586015     A    44525  0x0400000000004000  1.528138e+09  1.528138e+09
# 804627     A    33036  0x0400000000004000  1.528277e+09  1.528277e+09
# 1851939    A    12797  0x0400100000004000  1.540392e+09  1.540392e+09
# 1668246    A   231936  0x0400000000004000  1.540292e+09  1.540292e+09
# 2207446    A    37373  0x0000000000000044  1.540600e+09  1.540600e+09
# ...      ...      ...                 ...           ...           ...
# 2038739    A    26549  0x0400000000004000  1.540501e+09  1.540501e+09
# 2157532    A    10219  0x0400000000004000  1.540570e+09  1.540570e+09
# 557645     B    29472  0x0000000000000045  1.528114e+09  1.528114e+09
# 1569119    A   131762  0x0400000000004000  1.540288e+09  1.540288e+09
# 2084084    A    51108  0x0400000000004000  1.540527e+09  1.540527e+09
#
#           duration  numHdrDesc numHdrs       hdrDesc             srcMac  ...  \
# 586015    0.018387           1       3  eth:ipv4:tcp  ec:1a:59:83:28:11  ...
# 804627   36.145725           1       3  eth:ipv4:udp  ec:1a:59:83:28:11  ...
# 1851939   0.000635           1       3  eth:ipv4:udp  08:21:ef:3b:fc:e3  ...
# 1668246   9.820279           1       3  eth:ipv4:udp  b4:75:0e:ec:e5:a9  ...
# 2207446  45.985096           1       2       eth:arp  88:4a:ea:31:66:9d  ...
# ...            ...         ...     ...           ...                ...  ...
# 2038739   2.864801           1       3  eth:ipv4:tcp  ec:1a:59:83:28:11  ...
# 2157532   3.111271           1       3  eth:ipv4:tcp  ec:1a:59:83:28:11  ...
# 557645    0.000000           1       2       eth:arp  50:c7:bf:00:56:39  ...
# 1569119  39.895792           1       3  eth:ipv4:udp  ec:1a:59:83:28:11  ...
# 2084084   0.000000           1       3  eth:ipv4:udp  e0:76:d0:3f:00:ae  ...
#
#                  icmpBFTypH_TypL_Code   icmpTmGtw  icmpEchoSuccRatio  \
# 586015   0x00000000_0x00000000_0x0000  0x00000000                0.0
# 804627   0x00000000_0x00000000_0x0000  0x00000000                0.0
# 1851939  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 1668246  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 2207446  0x00000000_0x00000000_0x0000  0x00000000                0.0
# ...                               ...         ...                ...
# 2038739  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 2157532  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 557645   0x00000000_0x00000000_0x0000  0x00000000                0.0
# 1569119  0x00000000_0x00000000_0x0000  0x00000000                0.0
# 2084084  0x00000000_0x00000000_0x0000  0x00000000                0.0
#
#         icmpPFindex connSip connDip  connSipDip connSipDprt        connF  \
# 586015            0       9       1           2           2     0.222222
# 804627            0       6       6          10          10     1.666667
# 1851939           0      11       1         122         242    22.000000
# 1668246           0       8       5       11422       11421  1427.625000
# 2207446           0       0       0           0           0     0.000000
# ...             ...     ...     ...         ...         ...          ...
# 2038739           0       8       1           4           4     0.500000
# 2157532           0       8       1           4           4     0.500000
# 557645            0       0       0           0           0     0.000000
# 1569119           0       8       9          12           8     1.000000
# 2084084           0       7      13          12          12     1.714286
#
#         is_attack
# 586015       True
# 804627       True
# 1851939     False
# 1668246     False
# 2207446     False
# ...           ...
# 2038739      True
# 2157532      True
# 557645       True
# 1569119      True
# 2084084     False
#
# [50000 rows x 107 columns]
